# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('xaa.csv')
df.dtypes
# Out:
# TRIP ID                     int64
# START TIME                 object
# STOP TIME                  object
# BIKE ID                     int64
# TRIP DURATION               int64
# FROM STATION ID             int64
# FROM STATION NAME          object
# TO STATION ID               int64
# TO STATION NAME            object
# USER TYPE                  object
# GENDER                     object
# BIRTH YEAR                float64
# FROM LATITUDE             float64
# FROM LONGITUDE            float64
# FROM LOCATION              object
# TO LATITUDE               float64
# TO LONGITUDE              float64
# TO LOCATION                object
# Boundaries - ZIP Codes    float64
# Zip Codes                   int64
# Community Areas           float64
# Wards                     float64
# dtype: object

# %%
commonDestinations = df.groupby(["FROM STATION ID", "TO STATION ID"]).size().reset_index().rename(columns={0: "count"})
print commonDestinations
# Out:
#       FROM STATION ID  TO STATION ID  count
# 0                   2             45      1
# 1                   2            268      2
# 2                   3              3      9
# 3                   3              4      7
# 4                   3             33      2
# 5                   3             35      9
# 6                   3             39      2
# 7                   3             40      1
# 8                   3             41      1
# 9                   3             45      2
# 10                  3             59      2
# 11                  3             76      6
# 12                  3             85      3
# 13                  3            177      2
# 14                  3            192      1
# 15                  3            264      2
# 16                  3            268      4
# 17                  3            284      5
# 18                  3            338      2
# 19                  3            341      7
# ...

# %%
commonDestinations.groupby(['FROM STATION ID']).max()
# Out:
#                  TO STATION ID  count
# FROM STATION ID
# 2                          268      2
# 3                          341      9
# 4                          424      8
# 5                          321      3
# 6                          324     17
# 7                          337      3
# 9                          339      1
# 11                         424      1
# 12                         417      1
# 13                         501      4
# 14                         282      2
# 15                         359      2
# 16                         343      2
# 17                         374      2
# 18                         190      2
# 19                         346      2
# 20                         504      2
# 21                         434      2
# 22                         434      2
# 23                         286      1
# 24                         291      7
# 25                         318      4
# 26                         340      6
# ...

# %%
aggdf = commonDestinations.groupby(['count']).max()
# Out:
#        FROM STATION ID  TO STATION ID
# count
# 1                  618            617
# 2                  618            618
# 3                  616            616
# 4                  511            511
# 5                  459            454
# 6                  451            462
# 7                  294            463
# 8                  341            334
# 9                  334            192
# 10                 211            273
# 11                 284            284
# 12                 268            341
# 13                 341            249
# 14                 283            174
# 16                  35            268
# 17                  35            177
# 18                  76             35
# 19                  85            177
# 27                 268             35

# %%
commonFrom = df.loc[df["FROM STATION ID"] == 268]
commonFrom.loc[df["TO STATION ID"] == 35].groupby(["BIKE ID"]).drop('TO LATITUDE')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-56-de530329f538> in <module>()
#       1 commonFrom = df.loc[df["FROM STATION ID"] == 268]
# ----> 2 commonFrom.loc[df["TO STATION ID"] == 35].groupby(["BIKE ID"]).drop('TO LATITUDE')
#
# /Library/Python/2.7/site-packages/pandas/core/groupby.pyc in __getattr__(self, attr)
#     524             return self[attr]
#     525         if hasattr(self.obj, attr):
# --> 526             return self._make_wrapper(attr)
#     527
#     528         raise AttributeError("%r object has no attribute %r" %
#
# /Library/Python/2.7/site-packages/pandas/core/groupby.pyc in _make_wrapper(self, name)
#     538                    "using the 'apply' method".format(kind, name,
#     539                                                      type(self).__name__))
# --> 540             raise AttributeError(msg)
#     541
# ...
